# %% [markdown]
# # Data analysis

# %%
import pandas
import matplotlib.pyplot as plt

# %%
data = pandas.read_csv('./../../../data/test-hv2-LH.txt', delimiter='\t')

# %%
data[:][:1251]
# Out:
#         Time      Cz      C1      C2      C3      C4      C5      C6      C7  \
# 0    -2000.0 -1.2284 -3.0236  0.3244 -3.8951  1.4873 -2.6163  2.7419 -0.9852
# 1    -1996.0 -1.2743 -2.6513  0.2836 -3.3033  1.5541 -2.3393  2.5732 -1.1229
# 2    -1992.0 -1.2939 -2.2202  0.2854 -2.5777  1.7448 -1.9600  2.5685 -1.1842
# 3    -1988.0 -1.4882 -1.6886 -0.2216 -1.5296  1.1087 -1.0895  1.8001 -0.6351
# 4    -1984.0 -1.6450 -1.2063 -0.7496 -0.5138  0.3658 -0.1552  0.9720  0.0171
# 5    -1980.0 -2.6576 -1.6759 -2.0036 -0.2076 -0.8331  0.9007  0.3791  1.6155
# 6    -1976.0 -3.0548 -1.7163 -2.7911  0.1110 -1.9143  1.5706 -0.4720  2.5941
# 7    -1972.0 -3.3588 -1.7942 -3.4116  0.4640 -2.7485  2.4708 -0.9903  3.7071
# 8    -1968.0 -3.2871 -1.6558 -3.6735  0.6086 -3.3339  2.8308 -1.4959  4.3194
# 9    -1964.0 -3.2997 -1.5875 -3.8982  0.6374 -3.7109  2.9622 -1.8392  4.7259
# 10   -1960.0 -2.5507 -0.8433 -3.3494  1.0920 -3.4082  3.0238 -1.9178  4.4344
# ...

# %%
data['Cz']
# Out:
# 0       -1.2284
# 1       -1.2743
# 2       -1.2939
# 3       -1.4882
# 4       -1.6450
# 5       -2.6576
# 6       -3.0548
# 7       -3.3588
# 8       -3.2871
# 9       -3.2997
# 10      -2.5507
# 11      -2.0563
# 12      -1.7245
# 13      -0.5216
# 14      -0.1105
# 15       0.7436
# 16       0.5982
# 17       0.8205
# 18       0.6216
# 19       0.6223
# 20       0.3464
# 21       0.5021
# 22       0.6870
# 23       0.5054
# 24       0.4945
# 25       0.7790
# 26       1.1612
# 27       1.4923
# 28       1.7971
# 29       1.9739
#           ...
# 68720    1.2490
# 68721    0.4233
# 68722   -0.8221
# 68723   -1.4378
# 68724   -1.1985
# 68725   -0.2216
# 68726    0.3206
# 68727    1.6613
# 68728    2.1373
# 68729    1.9050
# 68730    1.4876
# 68731   -0.0190
# 68732   -0.4081
# 68733   -0.9234
# 68734   -0.8758
# 68735   -0.2154
# 68736    0.4299
# 68737    1.6223
# 68738    2.5291
# 68739    2.6540
# 68740    1.9225
# 68741    1.0940
# 68742    0.1756
# 68743   -0.1760
# ...

# %%
plt.plot(data['Cz'][:2500])
