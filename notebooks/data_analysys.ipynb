# %% [markdown]
# # Data analysis

# %%
import sys
import pandas
import matplotlib.pyplot as plt

# %%
local_path = './../../../data/test-hv2-LH.txt'
gdrive_path = '/content/drive/My Drive/eeg-project-19-20/data/test-hv2-LH.txt'

delimiter = '\t'
                            
if 'google.colab' in sys.modules:
  data = pandas.read_csv(gdrive_path, delimiter=delimiter)
else:
  data = pandas.read_csv(local_path, delimiter=delimiter)

# %%
data[:][:1251]
# Out:
#         Time      Cz      C1      C2  ...      Oz      O1      O2      Iz
# 0    -2000.0 -1.2284 -3.0236  0.3244  ... -1.0835 -1.1705  0.5312  0.7184
# 1    -1996.0 -1.2743 -2.6513  0.2836  ... -0.6579 -0.8726  1.0053  0.6076
# 2    -1992.0 -1.2939 -2.2202  0.2854  ... -0.3462 -0.7218  1.2593  0.5267
# 3    -1988.0 -1.4882 -1.6886 -0.2216  ...  0.0719 -0.3441  1.5513  0.7239
# 4    -1984.0 -1.6450 -1.2063 -0.7496  ...  0.4517  0.0709  1.7260  0.9730
# 5    -1980.0 -2.6576 -1.6759 -2.0036  ...  1.2827  1.0882  2.3183  2.2695
# 6    -1976.0 -3.0548 -1.7163 -2.7911  ...  1.6896  1.7676  2.5147  2.9274
# 7    -1972.0 -3.3588 -1.7942 -3.4116  ...  1.5499  1.8910  2.3584  3.0071
# 8    -1968.0 -3.2871 -1.6558 -3.6735  ...  1.0936  1.7393  1.8030  3.0747
# 9    -1964.0 -3.2997 -1.5875 -3.8982  ...  1.0262  1.9166  1.4787  3.3647
# 10   -1960.0 -2.5507 -0.8433 -3.3494  ...  0.3518  1.2800  0.7452  2.4979
# 11   -1956.0 -2.0563 -0.3569 -2.9110  ...  0.0638  0.9819  0.2766  2.1614
# ...

# %%
data['Cz']
# Out:
# 0       -1.2284
# 1       -1.2743
# 2       -1.2939
# 3       -1.4882
# 4       -1.6450
# 5       -2.6576
# 6       -3.0548
# 7       -3.3588
# 8       -3.2871
# 9       -3.2997
# 10      -2.5507
# 11      -2.0563
# 12      -1.7245
# 13      -0.5216
# 14      -0.1105
# 15       0.7436
# 16       0.5982
# 17       0.8205
# 18       0.6216
# 19       0.6223
# 20       0.3464
# 21       0.5021
# 22       0.6870
# 23       0.5054
# 24       0.4945
# 25       0.7790
# 26       1.1612
# 27       1.4923
# 28       1.7971
# 29       1.9739
#           ...
# 68720    1.2490
# 68721    0.4233
# 68722   -0.8221
# 68723   -1.4378
# 68724   -1.1985
# 68725   -0.2216
# 68726    0.3206
# 68727    1.6613
# 68728    2.1373
# 68729    1.9050
# 68730    1.4876
# 68731   -0.0190
# 68732   -0.4081
# 68733   -0.9234
# 68734   -0.8758
# 68735   -0.2154
# 68736    0.4299
# 68737    1.6223
# 68738    2.5291
# 68739    2.6540
# 68740    1.9225
# 68741    1.0940
# 68742    0.1756
# 68743   -0.1760
# ...

# %%
plt.plot(data['Cz'][:2500])
